# %%
import gonzag as gz
from gonzag.config import ldebug

# %%
file_sat = 'zarr_dt_global_alg_sla_vxxc_20170402_SARAL-Altika'
name_ssh_sat = 'adt_unfiltered'
file_mod = 'zarr_ssh_ORCA1_20170101_20171231_grid_T'
name_ssh_mod = 'ssh'
file_lsm_mod = 'zarr_ssh_ORCA1_20170101_20171231_grid_T'
name_lsm_mod = '_FillValue'

# %%
(it1,it2), (Nts,Ntm) = gz.GetEpochTimeOverlap( file_sat , file_mod )
# Out:
#  *** [GetTimeInfo()] Getting calendar/time info in zarr_dt_global_alg_sla_vxxc_20170402_SARAL-Altika ...
#    => time/record dimension is "time"
#  *** [GetTimeInfo()] Getting calendar/time info in zarr_ssh_ORCA1_20170101_20171231_grid_T ...
#    => time/record dimension is "time_counter"
#
#  *** [GetEpochTimeOverlap()] Earliest/latest dates:
#    => for satellite data: 2017-04-01T23:57:40.480926208 2017-04-02T23:14:42.618708992
#    => for model     data: 2017-01-16T12:00:00.000000000 2017-12-16T12:00:00.000000000

# %%
    print(' *** Time overlap between model and satellite in UNIX epoch time: it1, it2', it1,'--',it2)
    print('   => UTC: "'+str(it1)+'" to "'+str(it2)+'"\n')


    print('\n\n\n #####   M O D E L   2 D + T   D O M A I N   a.k.a.  S O U R C E   #####\n')
# Out:
#  *** Time overlap between model and satellite in UNIX epoch time: it1, it2 2017-04-01T23:57:40.480926208 -- 2017-04-02T23:14:42.618708992
#    => UTC: "2017-04-01T23:57:40.480926208" to "2017-04-02T23:14:42.618708992"
#
#
#
#
#  #####   M O D E L   2 D + T   D O M A I N   a.k.a.  S O U R C E   #####

# %%
clsm = name_lsm_mod
if name_lsm_mod=='_FillValue': clsm = name_lsm_mod+'@'+name_ssh_mod

# %%
from gonzag.zarrio import GetTimeEpochVector, GetModelCoor, GetModelLSM, Save2Dfield
mask = GetModelLSM( file_lsm_mod, clsm )
# Out:
#  *** what we use to define model land-sea mask:
#     => "_FillValue@ssh" in "zarr_ssh_ORCA1_20170101_20171231_grid_T"

# %%
mask
# Out:
# <xarray.DataArray 'ssh' (y: 292, x: 362)>
# dask.array<sub, shape=(292, 362), dtype=int64, chunksize=(146, 181), chunktype=numpy.ndarray>
# Coordinates:
#     nav_lat       (y, x) float64 dask.array<chunksize=(146, 181), meta=np.ndarray>
#     nav_lon       (y, x) float64 dask.array<chunksize=(146, 181), meta=np.ndarray>
#     time_counter  datetime64[ns] 2017-01-16T12:00:00
# Dimensions without coordinates: y, x

# %%
import numpy as nmp
import xarray as xr
XFLD=mask
ncfile='mask_model-zarr.nc'
name='mask'
(nj,ni) = nmp.shape(XFLD)

# %%
print(nj,ni)
# Out:
# 292 362

# %%
xtmp=XFLD

# %%
xtmp
# Out:
# <xarray.DataArray 'ssh' (y: 292, x: 362)>
# dask.array<sub, shape=(292, 362), dtype=int64, chunksize=(146, 181), chunktype=numpy.ndarray>
# Coordinates:
#     nav_lat       (y, x) float64 dask.array<chunksize=(146, 181), meta=np.ndarray>
#     nav_lon       (y, x) float64 dask.array<chunksize=(146, 181), meta=np.ndarray>
#     time_counter  datetime64[ns] 2017-01-16T12:00:00
# Dimensions without coordinates: y, x

# %%
clon='nav_lon'
clat='nav_lat'
foo=xr.DataArray(xtmp,dims=['y','x'])

# %%
cabout_nc = 'Created with Gonzag package => https://github.com/brodeau/gonzag'

# %%
unit=''
long_name=''
foo.name=name
foo.attrs["units"] = unit
foo.attrs["long_name"] = long_name

# %%
foo.to_netcdf(ncfile,'w', format='NETCDF4')

# %%
ds=foo.to_dataset()

# %%
ds.attrs=dict(about=cabout_nc)

# %%
ds.to_netcdf(ncfile,'w', format='NETCDF4')

# %%
Save2Dfield( 'mask_model.nc', mask, name='mask' )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-ff589370a767> in <module>
# ----> 1 Save2Dfield( 'mask_model.nc', mask, name='mask' )
#
# ~/Work/git/gonzag/gonzag/zarrio.py in Save2Dfield(ncfile, XFLD, xlon, xlat, name, unit, long_name, mask, clon, clat)
#     208
#     209     #Turn fields into dataset
# --> 210     foo=xr.DataArray(xtmp,dims=['y','x'],coords=[clat,clon])
#     211     foo.name=name
#     212     foo.attrs["units"] = unit
#
# ~/anaconda2/envs/gonzag/lib/python3.9/site-packages/xarray/core/dataarray.py in __init__(self, data, coords, dims, name, attrs, indexes, fastpath)
#     407             data = _check_data_shape(data, coords, dims)
#     408             data = as_compatible_data(data)
# --> 409             coords, dims = _infer_coords_and_dims(data.shape, coords, dims)
#     410             variable = Variable(dims, data, attrs, fastpath=True)
#     411             indexes = dict(
#
# ~/anaconda2/envs/gonzag/lib/python3.9/site-packages/xarray/core/dataarray.py in _infer_coords_and_dims(shape, coords, dims)
#     141         for dim, coord in zip(dims, coords):
#     142             var = as_variable(coord, name=dim)
# --> 143             var.dims = (dim,)
#     144             new_coords[dim] = var.to_index_variable()
#     145
#
# ~/anaconda2/envs/gonzag/lib/python3.9/site-packages/xarray/core/variable.py in dims(self, value)
#     594     @dims.setter
#     595     def dims(self, value):
# --> 596         self._dims = self._parse_dimensions(value)
#     597
#     598     def _parse_dimensions(self, dims):
#
# ~/anaconda2/envs/gonzag/lib/python3.9/site-packages/xarray/core/variable.py in _parse_dimensions(self, dims)
#     601         dims = tuple(dims)
#     602         if len(dims) != self.ndim:
# --> 603             raise ValueError(
#     604                 "dimensions %s must have the same length as the "
#     605                 "number of data dimensions, ndim=%s" % (dims, self.ndim)
#
# ValueError: dimensions ('y',) must have the same length as the number of data dimensions, ndim=0
